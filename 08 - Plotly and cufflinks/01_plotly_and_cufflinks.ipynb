# %% [markdown]
# # Plotly and Cufflinks

# %% [markdown]
# ## Plotly
# * an interactive visualization library
# * [plotly website](https://plotly.com/)
#
# ## Cufflinks
# * connects plotly with pandas
# * [cufflinks github](https://github.com/santosjorge/cufflinks)

# %%
import pandas as pd
import numpy as np 
# %matplotlib inline

# %%
from plotly import __version__
import chart_studio.plotly as py

# %%
print(__version__)
# Out:
# 5.6.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %% [markdown]
# ### `init_notebook_mode(connected=True)` : connect session
# * `connected` : True / connect js to jupyterlab

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### `cf.go_offline()`: use plotly in offline mode

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# DATA 
df = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0   0.403020  0.458701 -0.927643  0.464634
# 1   3.980079 -0.052222  1.433210 -1.362343
# 2   1.291855 -2.974681  0.978899 -0.608890
# 3   0.381821 -1.019440  0.269412  0.000607
# 4   1.168064  0.703299 -0.303334 -0.217661
# ..       ...       ...       ...       ...
# 95 -0.312203  0.698928  1.087676 -1.442627
# 96  0.562404 -0.866735  1.254272  1.000721
# 97  1.615698  0.857801 -0.716177 -0.416485
# 98 -0.835280 -0.753251 -0.115623 -0.505800
# 99 -0.842714  0.129540  1.246060  1.069824
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({'Category' : ['A', 'B', 'C'], 'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### `df.iplot()` : create an interactive plot

# %%
df.iplot()

# %% [markdown]
# ### `df.iplot()`
# * `kind='scatter'`
# * `x='A', y='B'`
# * `mode='markers'`
# * `size=20`

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers', size=20)

# %%
df2.iplot(kind='bar', x='Category', y='Values')

# %% [markdown]
# ### `df.sum().iplot()` : aggregation functions(count...) can be used

# %%
df.sum().iplot(kind='bar')

# %%
df.iplot(kind='box')

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y': [10,20,30,20,10], 'z': [500, 400, 300, 200, 100]})

# %%
df3.iplot(kind='surface')

# %% [markdown]
# * `colorscale` : 'rdylbu', each letter stands for the initial letter of the color

# %%
df3.iplot(kind='surface', colorscale='rdylbu')

# %%
df['A'].iplot(kind='hist', bins=25)

# %%
df.iplot(kind='hist', bins=25)

# %% [markdown]
# * `kind='spread'` show the spread between variables

# %%
df[['A', 'B']].iplot(kind='spread')
# Out:
# C:\Users\slaki\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\slaki\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
df.iplot(kind='bubble', x='A', y='B', size='C')

# %% [markdown]
# ### `df.scatter_matrix()` : scatter plots for all the variables
# * every variable has to be numerical variable

# %%
df.scatter_matrix()
